# %%
import pandas as pd
import numpy as np
from collections import Counter
# !pip install textblob
from textblob import TextBlob

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

#from nltk.corpus import stopwords
#import nltk
#nltk.download('stopwords')
# Out:
# Requirement already satisfied: textblob in /opt/anaconda3/lib/python3.8/site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /opt/anaconda3/lib/python3.8/site-packages (from textblob) (3.6.1)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (7.1.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (4.59.0)
# Requirement already satisfied: regex in /opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (2021.4.4)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (1.0.1)
# [nltk_data] Downloading package punkt to /Users/home/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/home/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
#textblob.download_corpora
#import textblob
#from textblob import TextBlob

# %%
df = pd.read_csv('data_initialEDA.csv')
df
# Out:
#        Stars                                             Review
# 0          1  I got 'new' tires from them and within two wee...
# 1          1  Don't waste your time. We had two different pe...
# 2          1  All I can say is the worst! We were the only 2...
# 3          1  I have been to this restaurant twice and was d...
# 4          1  Food was NOT GOOD at all! My husband & I ate h...
# ...      ...                                                ...
# 49873      1  Just wanted to write a review to chip in with ...
# 49874      5  Great ambience. Great drinks. Great food. I lo...
# 49875      4  I have been to the other Monks locations so I ...
# 49876      2  Don't go here. I know you might want to try it...
# 49877      1  Buffet was recently open after renovation so m...
#
# [49878 rows x 2 columns]

# %%
#Counter(" ".join(df["Review"]).split()).most_common()
#df['review_without_stopwords'] = df['Review'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
#stop = stopwords.words('english')

# %%
def get_adjectives(text):
    blob = TextBlob(text)
    return [ word for (word,tag) in blob.tags if tag == "JJ"]

df['adjectives'] = df['Review'].apply(get_adjectives)

# %%
five_star = df[df['Stars'] == 5]
one_star = df[df['Stars'] == 1]

# %%
five_star['adjectives'] = five_star.adjectives.apply(' '.join)
five_star
# Out:
# <ipython-input-39-93a9d0b34a7d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   five_star['adjectives'] = five_star.adjectives.apply(' '.join)
#        Stars                                             Review  \
# 28         5  This is by far my favorite Panera location in ...
# 33         5  This place is amazing!!! Jim is a great artist...
# 36         5  This cafe's espresso drinks are on par with th...
# 44         5  The first time I came here, I waited in line f...
# 60         5  Our favorite place to go for chocolate peanut ...
# ...      ...                                                ...
# 49862      5  I had a bad customer service expensive at firs...
# 49863      5  My first YEE! It was definitely one to remembe...
# 49867      5  I am so excited that Sephora is now located in...
# 49868      5  Finally! Shake shack opened their doors! It ha...
# 49874      5  Great ambience. Great drinks. Great food. I lo...
#
#                                               adjectives
# 28              favorite good great free toasted chicken
# 33                                         amazing great
# 36                                    espresso artisinal
# 44     first bad dangerous some.Do guilty fabulous de...
# 60                                    favorite delicious
# ...                                                  ...
# 49862                     bad first great friendly cheap
# 49863  first such nice delicious delicious friendly g...
# 49867              excited first free only few free much
# 49868             nice east attentive friendly Good good
# 49874                                  Great Great Great
#
# [9959 rows x 3 columns]

# %%
Counter(" ".join(five_star["adjectives"]).split()).most_common()
# Out:
# [('great', 4659),
#  ('good', 3687),
#  ('nice', 1551),
#  ('other', 1473),
#  ('delicious', 1462),
#  ('friendly', 1259),
#  ('little', 1220),
#  ('amazing', 1067),
#  ('new', 1049),
#  ('fresh', 1041),
#  ('first', 1024),
#  ('awesome', 892),
#  ('favorite', 862),
#  ('many', 847),
#  ('few', 830),
#  ('much', 810),
#  ('sure', 807),
#  ('next', 773),
#  ('happy', 755),
#  ('perfect', 679),
#  ('last', 674),
#  ('different', 660),
#  ('excellent', 647),
#  ('small', 598),
#  ('wonderful', 590),
#  ('big', 566),
#  ('super', 559),
#  ('hot', 550),
#  ('free', 544),
#  ('clean', 540),
#  ('fantastic', 500),
#  ('full', 496),
#  ('only', 445),
#  ('same', 445),
#  ('special', 444),
#  ('bad', 433),
#  ('sweet', 433),
#  ('old', 432),
#  ('huge', 426),
#  ('beautiful', 425),
#  ('large', 416),
#  ('helpful', 413),
#  ('tasty', 408),
#  ('able', 401),
#  ('right', 395),
#  ('whole', 381),
#  ('own', 372),
#  ('local', 362),
#  ('such', 348),
#  ('reasonable', 346),
#  ('worth', 343),
#  ('high', 343),
#  ('long', 334),
#  ('quick', 322),
#  ('professional', 318),
#  ('several', 318),
#  ('top', 315),
#  ('hard', 308),
#  ('comfortable', 304),
#  ('real', 298),
#  ('open', 295),
#  ('busy', 293),
#  ('Great', 286),
#  ('easy', 285),
#  ('attentive', 281),
#  ('cool', 280),
#  ('extra', 275),
#  ('second', 244),
#  ('unique', 241),
#  ('glad', 237),
#  ('red', 236),
#  ('regular', 232),
#  ('incredible', 231),
#  ('wrong', 229),
#  ('entire', 228),
#  ('cheese', 227),
#  ('Italian', 226),
#  ('i', 218),
#  ('green', 217),
#  ('main', 213),
#  ('authentic', 209),
#  ('white', 209),
#  ('Good', 209),
#  ('expensive', 206),
#  ('pretty', 203),
#  ('short', 202),
#  ('warm', 198),
#  ('outstanding', 192),
#  ('knowledgeable', 192),
#  ('available', 185),
#  ('cheap', 183),
#  ('ready', 179),
#  ('impressed', 177),
#  ('fabulous', 166),
#  ('fine', 164),
#  ('flavorful', 162),
#  ('fried', 161),
#  ('true', 155),
#  ('enough', 153),
#  ('soft', 151),
#  ('late', 148),
#  ('simple', 147),
#  ('early', 146),
#  ('light', 143),
#  ('outside', 143),
#  ('black', 142),
#  ('modern', 142),
#  ('healthy', 140),
#  ('past', 139),
#  ('decent', 138),
#  ('single', 138),
#  ('fun', 138),
#  ('pleasant', 134),
#  ('garlic', 128),
#  ('cold', 126),
#  ('Chinese', 125),
#  ('French', 123),
#  ('personal', 121),
#  ('Excellent', 120),
#  ('fast', 119),
#  ('generous', 119),
#  ('fish', 118),
#  ('Overall', 117),
#  ('phenomenal', 115),
#  ('rich', 115),
#  ('Japanese', 112),
#  ('affordable', 112),
#  ('quiet', 112),
#  ('pleased', 110),
#  ('due', 107),
#  ('Mexican', 106),
#  ('traditional', 105),
#  ('crazy', 105),
#  ('hungry', 104),
#  ('exceptional', 104),
#  ('close', 102),
#  ('fair', 102),
#  ('overall', 101),
#  ('interesting', 101),
#  ('usual', 99),
#  ('low', 98),
#  ('gorgeous', 98),
#  ('french', 98),
#  ('yummy', 95),
#  ('typical', 95),
#  ('young', 95),
#  ('wine', 95),
#  ('classic', 94),
#  ('cute', 94),
#  ('willing', 93),
#  ('casual', 93),
#  ('possible', 92),
#  ('vegetarian', 90),
#  ('grilled', 89),
#  ('tiny', 87),
#  ('thin', 86),
#  ('courteous', 86),
#  ('frozen', 85),
#  ('live', 85),
#  ('efficient', 85),
#  ('disappointed', 84),
#  ('Happy', 84),
#  ('previous', 84),
#  ('prepared', 83),
#  ('Asian', 83),
#  ('patient', 83),
#  ('complete', 83),
#  ('pricey', 83),
#  ('creamy', 82),
#  ('strong', 82),
#  ('normal', 81),
#  ('table', 80),
#  ('complimentary', 79),
#  ('lucky', 79),
#  ('satisfied', 78),
#  ('private', 78),
#  ('*', 78),
#  ('spacious', 77),
#  ('personable', 76),
#  ('original', 76),
#  ('polite', 75),
#  ('deep', 75),
#  ('various', 74),
#  ('Indian', 74),
#  ('funny', 74),
#  ('half', 74),
#  ('multiple', 73),
#  ('rare', 73),
#  ('delish', 73),
#  ('dry', 73),
#  ('prime', 73),
#  ('wide', 72),
#  ('mixed', 72),
#  ('spectacular', 71),
#  ('fancy', 71),
#  ('creative', 70),
#  ('romantic', 70),
#  ('loud', 70),
#  ('negative', 69),
#  ('important', 68),
#  ('daily', 68),
#  ('flat', 68),
#  ('solid', 67),
#  ('empty', 67),
#  ('outdoor', 67),
#  ('actual', 67),
#  ('positive', 66),
#  ('excited', 66),
#  ('knowledgable', 66),
#  ('safe', 66),
#  ('separate', 66),
#  ('hidden', 65),
#  ('Next', 65),
#  ('vegan', 64),
#  ('like', 64),
#  ('lovely', 64),
#  ('additional', 64),
#  ('back', 63),
#  ('enjoyable', 63),
#  ('giant', 63),
#  ('double', 63),
#  ('chicken', 62),
#  ('particular', 62),
#  ('prompt', 62),
#  ('thick', 61),
#  ('slow', 61),
#  ('impressive', 61),
#  ('impeccable', 61),
#  ('delightful', 60),
#  ('Friendly', 60),
#  ('dark', 60),
#  ('general', 60),
#  ('wait', 60),
#  ('third', 60),
#  ('picky', 59),
#  ('..', 59),
#  ('heavy', 59),
#  ('absolute', 58),
#  ('sour', 57),
#  ('terrific', 57),
#  ('inexpensive', 56),
#  ('recent', 56),
#  ('couple', 56),
#  ('First', 55),
#  ('similar', 55),
#  ('clear', 55),
#  ('difficult', 55),
#  ('natural', 54),
#  ('American', 54),
#  ('total', 54),
#  ('AMAZING', 54),
#  ('thorough', 53),
#  ('popular', 53),
#  ('nail', 53),
#  ('Fantastic', 53),
#  ('Such', 53),
#  ('blue', 52),
#  ('major', 52),
#  ('front', 52),
#  ('salad', 52),
#  ('serious', 51),
#  ('classy', 51),
#  ('upscale', 51),
#  ('ok', 51),
#  ('olive', 51),
#  ('go-to', 50),
#  ('welcome', 50),
#  ('secret', 50),
#  ('....', 50),
#  ('relaxing', 50),
#  ('organic', 50),
#  ('wish', 49),
#  ('Last', 49),
#  ('limited', 49),
#  ('certain', 48),
#  ('lunch', 48),
#  ('average', 48),
#  ('basic', 48),
#  ('Amazing', 48),
#  ('extensive', 47),
#  ('massive', 47),
#  ('superb', 47),
#  ('weird', 46),
#  ('dessert', 46),
#  ('bright', 45),
#  ('famous', 45),
#  ('standard', 45),
#  ('tough', 45),
#  ('memorable', 44),
#  ('nervous', 44),
#  ('dish', 44),
#  ('sushi', 44),
#  ('smooth', 43),
#  ('lemon', 43),
#  ('consistent', 43),
#  ('GREAT', 42),
#  ('poor', 42),
#  ('relaxed', 42),
#  ('baked', 42),
#  ('culinary', 42),
#  ('elegant', 42),
#  ('smoked', 42),
#  ('noodle', 41),
#  ('Other', 41),
#  ('fat', 41),
#  ('iced', 41),
#  ('numerous', 41),
#  ('intimate', 41),
#  ('moist', 40),
#  ('sandwich', 40),
#  ('sad', 40),
#  ('weekly', 40),
#  ('recommended', 40),
#  ('cozy', 40),
#  ('un', 40),
#  ('convenient', 39),
#  ('italian', 39),
#  ('interested', 39),
#  ('surprised', 39),
#  ('u', 39),
#  ('informative', 39),
#  ('adorable', 39),
#  ('u00e0', 39),
#  ('Korean', 38),
#  ('neat', 37),
#  ('Awesome', 37),
#  ('stellar', 37),
#  ('downtown', 37),
#  ('trendy', 37),
#  ('honest', 37),
#  ('Fresh', 36),
#  ('grand', 36),
#  ('sick', 36),
#  ('raw', 35),
#  ('vegetable', 35),
#  ('greasy', 35),
#  ('pizza', 35),
#  ('skeptical', 35),
#  ('fellow', 34),
#  ('seasonal', 34),
#  ('grateful', 34),
#  ('Free', 34),
#  ('necessary', 34),
#  ('Nice', 33),
#  ('birthday', 33),
#  ('dental', 33),
#  ('sorry', 33),
#  ('lazy', 33),
#  ('Greek', 33),
#  ('Second', 32),
#  ('wild', 32),
#  ('careful', 32),
#  ('genuine', 32),
#  ('Spanish', 32),
#  ('foie', 32),
#  ('ta', 32),
#  ('joint', 31),
#  ('Delicious', 31),
#  ('future', 31),
#  ('GOOD', 31),
#  ('sooo', 31),
#  ('crispy', 31),
#  ('roasted', 31),
#  ('ridiculous', 30),
#  ('east', 30),
#  ('terrible', 30),
#  ('fluffy', 30),
#  ('specific', 30),
#  ('carne', 30),
#  ('near', 30),
#  ('scrumptious', 30),
#  ('everyday', 30),
#  ('savory', 29),
#  ('afraid', 29),
#  ('competitive', 29),
#  ('final', 29),
#  ('odd', 29),
#  ('legit', 29),
#  ('yellow', 29),
#  ('unbelievable', 29),
#  ('auch', 29),
#  ('Incredible', 28),
#  ('Wonderful', 28),
#  ('brown', 28),
#  ('frequent', 28),
#  ('straight', 28),
#  ('seasoned', 28),
#  ('unusual', 28),
#  ('mexican', 27),
#  ('asian', 27),
#  ('hilarious', 27),
#  ('welcoming', 27),
#  ('initial', 27),
#  ('Irish', 27),
#  ('current', 26),
#  ('non', 26),
#  ('eclectic', 26),
#  ('following', 26),
#  ('lamb', 26),
#  ('rental', 26),
#  ('Big', 26),
#  ('smart', 26),
#  ('dirty', 26),
#  ('Huge', 26),
#  ('sticky', 26),
#  ('familiar', 25),
#  ('Many', 25),
#  ('crowded', 25),
#  ('horrible', 25),
#  ('minor', 25),
#  ('comparable', 25),
#  ('facial', 25),
#  ('Hawaiian', 25),
#  ('proper', 25),
#  ('added', 25),
#  ('spa', 25),
#  ('shrimp', 25),
#  ('exact', 25),
#  ('n', 25),
#  ('gluten', 25),
#  ('monthly', 25),
#  ('overwhelming', 25),
#  ('adventurous', 25),
#  ('individual', 24),
#  ('eager', 24),
#  ('human', 24),
#  ('obvious', 24),
#  ('likely', 24),
#  ('detailed', 24),
#  ('delectable', 24),
#  ('present', 24),
#  ('Green', 24),
#  ('pulled', 24),
#  ('correct', 24),
#  ('tall', 24),
#  ('confident', 24),
#  ('slight', 24),
#  ('sexy', 24),
#  ('bread', 23),
#  ('tight', 23),
#  ('anniversary', 23),
#  ('further', 23),
#  ('common', 23),
#  ('steak', 23),
#  ('hooked', 23),
#  ('reliable', 23),
#  ('appropriate', 23),
#  ('vast', 23),
#  ('comfy', 23),
#  ('animal', 23),
#  ('timely', 23),
#  ('chinese', 23),
#  ('flexible', 23),
#  ('3-4', 23),
#  ('Clean', 23),
#  ('filling', 23),
#  ('nearby', 22),
#  ('menu', 22),
#  ('Wish', 22),
#  ('middle', 22),
#  ('superior', 22),
#  ('complex', 22),
#  ('crisp', 22),
#  ('guilty', 21),
#  ('spicy', 21),
#  ('gracious', 21),
#  ('Perfect', 21),
#  ('5-star', 21),
#  ('ample', 21),
#  ('homemade', 21),
#  ('plentiful', 21),
#  ('Vietnamese', 21),
#  ('dive', 21),
#  ('dead', 21),
#  ('inside', 21),
#  ('Large', 21),
#  ('recommend', 20),
#  ('unexpected', 20),
#  ('top-notch', 20),
#  ('worried', 20),
#  ('central', 20),
#  ('eggplant', 20),
#  ('uncomfortable', 20),
#  ('plenty', 20),
#  ('bottled', 20),
#  ('north', 20),
#  ('favourite', 20),
#  ('luxurious', 20),
#  ('delicate', 20),
#  ('stunning', 19),
#  ('loose', 19),
#  ('OK', 19),
#  ('chipotle', 19),
#  ('definite', 19),
#  ('diet', 19),
#  ('soooo', 19),
#  ('upbeat', 19),
#  ('Top', 19),
#  ('quality', 19),
#  ('social', 19),
#  ('thankful', 19),
#  ('west', 19),
#  ('crunchy', 19),
#  ('former', 19),
#  ('alcoholic', 19),
#  ('sophisticated', 19),
#  ('bottle', 19),
#  ('colorful', 19),
#  ('German', 18),
#  ('inviting', 18),
#  ('energetic', 18),
#  ('tender', 18),
#  ('random', 18),
#  ('online', 18),
#  ('soggy', 18),
#  ('southern', 18),
#  ('dog', 18),
#  ('chic', 18),
#  ('gentle', 18),
#  ('puppy', 18),
#  ('awful', 18),
#  ('corporate', 18),
#  ('whipped', 18),
#  ('aware', 18),
#  ('pet', 18),
#  ('Beautiful', 18),
#  ('medical', 18),
#  ('Little', 18),
#  ('make', 18),
#  ('entertaining', 18),
#  ('ultimate', 18),
#  ('oh', 18),
#  ('side', 18),
#  ('pretentious', 18),
#  ('ideal', 18),
#  ('Venetian', 18),
#  ('refreshing', 18),
#  ('key', 17),
#  ('attractive', 17),
#  ('unassuming', 17),
#  ('talented', 17),
#  ('strange', 17),
#  ('contemporary', 17),
#  ('rude', 17),
#  ('pure', 17),
#  ('stupid', 17),
#  ('mini', 17),
#  ('fatty', 17),
#  ('garlicky', 17),
#  ('addictive', 17),
#  ('divine', 17),
#  ('gigantic', 17),
#  ('unlimited', 17),
#  ('packed', 17),
#  ('restaurant', 17),
#  ('interior', 17),
#  ('mild', 17),
#  ('soy', 17),
#  ('truffle', 17),
#  ('le', 17),
#  ('une', 17),
#  ('deli', 16),
#  ('rustic', 16),
#  ('glorious', 16),
#  ('accurate', 16),
#  ('Small', 16),
#  ('experienced', 16),
#  ('enormous', 16),
#  ('impossible', 16),
#  ('indoor', 16),
#  ('ten', 16),
#  ('magical', 16),
#  ('thoughtful', 16),
#  ('broken', 16),
#  ('pushy', 16),
#  ('bean', 16),
#  ('ice', 16),
#  ('damn', 16),
#  ('public', 16),
#  ('shredded', 16),
#  ('crappy', 16),
#  ('Real', 16),
#  ('exciting', 16),
#  ('artistic', 16),
#  ('diverse', 15),
#  ('European', 15),
#  ('enthusiastic', 15),
#  ('decadent', 15),
#  ('drunk', 15),
#  ('salmon', 15),
#  ('English', 15),
#  ('brunch', 15),
#  ('rough', 15),
#  ('tried', 15),
#  ('Sure', 15),
#  ('ONLY', 15),
#  ('hesitant', 15),
#  ('native', 15),
#  ('respectful', 15),
#  ('unreal', 15),
#  ('used', 15),
#  ('polish', 15),
#  ('concerned', 15),
#  ('left', 15),
#  ('exotic', 15),
#  ('entree', 15),
#  ('Much', 15),
#  ('atmosphere', 15),
#  ('urban', 15),
#  ('proud', 15),
#  ('okay', 15),
#  ('snow', 15),
#  ('stylish', 15),
#  ('outrageous', 15),
#  ('physical', 15),
#  ('toasted', 14),
#  ('subtle', 14),
#  ('awkward', 14),
#  ('Ca', 14),
#  ('potato', 14),
#  ('innovative', 14),
#  ('national', 14),
#  ('understanding', 14),
#  ('Red', 14),
#  ('weak', 14),
#  ('salsa', 14),
#  ('couch', 14),
#  ('successful', 14),
#  ('significant', 14),
#  ('international', 14),
#  ('south', 14),
#  ('2-3', 14),
#  ('humble', 14),
#  ('balsamic', 14),
#  ('apparent', 14),
#  ('mad', 14),
#  ('home-made', 14),
#  ('peaceful', 14),
#  ('remarkable', 14),
#  ('extraordinary', 14),
#  ('eating', 14),
#  ('golden', 14),
#  ('steady', 14),
#  ('endless', 14),
#  ('ahi', 14),
#  ('plus', 14),
#  ('parmesan', 14),
#  ('soo', 14),
#  ('gel', 14),
#  ('brilliant', 14),
#  ('und', 14),
#  ('upper', 13),
#  ('gross', 13),
#  ('unnecessary', 13),
#  ('lame', 13),
#  ('surprising', 13),
#  ('comic', 13),
#  ('upstairs', 13),
#  ('retail', 13),
#  ('constant', 13),
#  ('sensitive', 13),
#  ('Worth', 13),
#  ('greek', 13),
#  ('shy', 13),
#  ('it.The', 13),
#  ('Mongolian', 13),
#  ('Open', 13),
#  ('screen', 13),
#  ('cafe', 13),
#  ('uni', 13),
#  ('partial', 13),
#  ('quite', 13),
#  ('Brazilian', 13),
#  ('High', 13),
#  ('worthy', 13),
#  ('ordinary', 13),
#  ('premium', 13),
#  ('na', 13),
#  ('intense', 13),
#  ('bitter', 13),
#  ('pickled', 13),
#  ('to-go', 13),
#  ('shaved', 13),
#  ('oz', 12),
#  ('Wait', 12),
#  ('.....', 12),
#  ('eggs', 12),
#  ('permanent', 12),
#  ('freakin', 12),
#  ('accessible', 12),
#  ('handy', 12),
#  ('bubble', 12),
#  ('approachable', 12),
#  ('alternative', 12),
#  ('flaky', 12),
#  ('critical', 12),
#  ('die', 12),
#  ('allergic', 12),
#  ('unbeatable', 12),
#  ('edible', 12),
#  ('alive', 12),
#  ('mere', 12),
#  ('pregnant', 12),
#  ('quaint', 12),
#  ('lil', 12),
#  ('stressful', 12),
#  ('hectic', 12),
#  ('dining', 12),
#  ('pineapple', 12),
#  ('obnoxious', 12),
#  ('musical', 12),
#  ('4-5', 12),
#  ('combo', 12),
#  ('cheerful', 12),
#  ('historic', 12),
#  ('independent', 12),
#  ('strawberry', 12),
#  ('cooked', 12),
#  ('succulent', 12),
#  ('curious', 12),
#  ('military', 12),
#  ('sized', 12),
#  ('capable', 12),
#  ('tasteful', 12),
#  ('hearty', 12),
#  ('dangerous', 11),
#  ('seared', 11),
#  ('shiny', 11),
#  ('fit', 11),
#  ('beaten', 11),
#  ('mid', 11),
#  ('accommodating', 11),
#  ('Reasonable', 11),
#  ('mine', 11),
#  ('loyal', 11),
#  ('tad', 11),
#  ('above', 11),
#  ('chill', 11),
#  ('mean', 11),
#  ('occasional', 11),
#  ('plain', 11),
#  ('immaculate', 11),
#  ('stop', 11),
#  ('trained', 11),
#  ('immediate', 11),
#  ('responsible', 11),
#  ('western', 11),
#  ('calm', 11),
#  ('veggie', 11),
#  ('messy', 11),
#  ('avocado', 11),
#  ('spent', 11),
#  ('active', 11),
#  ('responsive', 11),
#  ('hefty', 11),
#  ('tricky', 11),
#  ('w/', 11),
#  ('formal', 11),
#  ('noisy', 11),
#  ('minute', 11),
#  ('kinda', 11),
#  ('unpretentious', 11),
#  ('equal', 11),
#  ('strip', 11),
#  ('holy', 11),
#  ('spotless', 11),
#  ('wet', 11),
#  ('chocolate', 11),
#  ('sunny', 11),
#  ('sleek', 11),
#  ('Sicilian', 10),
#  ('cant', 10),
#  ('uptown', 10),
#  ('fav', 10),
#  ('insane', 10),
#  ('Ethiopian', 10),
#  ('female', 10),
#  ('legal', 10),
#  ('skin', 10),
#  ('indian', 10),
#  ('electric', 10),
#  ('Affordable', 10),
#  ('enjoyed', 10),
#  ('appointment', 10),
#  ('beat', 10),
#  ('countless', 10),
#  ('wooden', 10),
#  ('Total', 10),
#  ('mediocre', 10),
#  ('scary', 10),
#  ('Russian', 10),
#  ('fortunate', 10),
#  ('sliced', 10),
#  ('disappointing', 10),
#  ('Fabulous', 10),
#  ('exclusive', 10),
#  ('annual', 10),
#  ('addicted', 10),
#  ('ur', 10),
#  ('Unbelievable', 10),
#  ('Authentic', 10),
#  ('freaking', 10),
#  ('drive', 10),
#  ('cheesy', 10),
#  ('Scottish', 10),
#  ('funky', 10),
#  ('painful', 10),
#  ('caramelized', 10),
#  ('+', 10),
#  ('chewy', 10),
#  ('jealous', 10),
#  ('steep', 10),
#  ('Turkish', 10),
#  ('stuffed', 10),
#  ('boring', 10),
#  ('lime', 10),
#  ('infused', 10),
#  ('rosemary', 10),
#  ('magic', 10),
#  ('fake', 10),
#  ('visual', 10),
#  ('popcorn', 10),
#  ('japanese', 10),
#  ('naked', 10),
#  ('thank', 10),
#  ('ive', 10),
#  ('nicht', 10),
#  ('ich', 10),
#  ('espresso', 9),
#  ('kitchen', 9),
#  ('upfront', 9),
#  ('floral', 9),
#  ('wary', 9),
#  ('hair', 9),
#  ('gourmet', 9),
#  ('sharp', 9),
#  ('korean', 9),
#  ('ordered', 9),
#  ('Southern', 9),
#  ('weight', 9),
#  ('crawfish', 9),
#  ('thrilled', 9),
#  ('electronic', 9),
#  ('opposite', 9),
#  ('foreign', 9),
#  ('tropical', 9),
#  ('darn', 9),
#  ('else', 9),
#  ('effective', 9),
#  ('patio', 9),
#  ('mouth', 9),
#  ('dried', 9),
#  ('pecan', 9),
#  ('Belgian', 9),
#  ('anxious', 9),
#  ('shot', 9),
#  ('primary', 9),
#  ('square', 9),
#  ('brief', 9),
#  ('taco', 9),
#  ('im', 9),
#  ('infamous', 9),
#  ('Local', 9),
#  ('satisfying', 9),
#  ('2nd', 9),
#  ('sashimi', 9),
#  ('picnic', 9),
#  ('fourth', 9),
#  ('bloody', 9),
#  ('nose', 9),
#  ('drunken', 9),
#  ('turkey', 9),
#  ('steamed', 9),
#  ('shuttle', 9),
#  ('tremendous', 9),
#  ('Me-', 9),
#  ('foot', 9),
#  ('freshly', 9),
#  ('pita', 9),
#  ('mellow', 9),
#  ('vibrant', 9),
#  ('vous', 9),
#  ('coming', 9),
#  ('drink', 9),
#  ('touch', 9),
#  ('come', 9),
#  ('complementary', 9),
#  ('flavored', 9),
#  ('maple', 9),
#  ('Caprese', 9),
#  ('foodie', 9),
#  ('In-N-Out', 9),
#  ('pasta', 8),
#  ('cultural', 8),
#  ('understatement', 8),
#  ('chopped', 8),
#  ('broad', 8),
#  ('overpriced', 8),
#  ('Special', 8),
#  ('hole-in-the-wall', 8),
#  ('exquisite', 8),
#  ('gravy', 8),
#  ('Side', 8),
#  ('biased', 8),
#  ('sketchy', 8),
#  ('closed', 8),
#  ('cordial', 8),
#  ('upset', 8),
#  ('library', 8),
#  ('pampered', 8),
#  ('Super', 8),
#  ('serene', 8),
#  ('shady', 8),
#  ('trustworthy', 8),
#  ('conscious', 8),
#  ('marinated', 8),
#  ('hands-down', 8),
#  ('talkative', 8),
#  ('gluten-free', 8),
#  ('hundred', 8),
#  ('minimum', 8),
#  ('sourdough', 8),
#  ('anywhere', 8),
#  ('mile', 8),
#  ('cinnamon', 8),
#  ('out-of-town', 8),
#  ('take-out', 8),
#  ('down', 8),
#  ('tofu', 8),
#  ('al', 8),
#  ('industrial', 8),
#  ('angry', 8),
#  ('custom', 8),
#  ('sufficient', 8),
#  ('extended', 8),
#  ('10-15', 8),
#  ('ethnic', 8),
#  ('skinny', 8),
#  ('mega', 8),
#  ('male', 8),
#  ('unable', 8),
#  ('peak', 8),
#  ('Went', 8),
#  ('content', 8),
#  ('unforgettable', 8),
#  ('wow', 8),
#  ('mashed', 8),
#  ('evil', 8),
#  ('overdue', 8),
#  ('u00a0The', 8),
#  ('touristy', 8),
#  ('bolognese', 8),
#  ('Due', 8),
#  ('personalized', 8),
#  ('truly', 8),
#  ('beloved', 8),
#  ('jalapeno', 8),
#  ('queen', 8),
#  ('dim', 8),
#  ('tired', 8),
#  ('check-in', 8),
#  ('tea', 8),
#  ('neighborhood', 8),
#  ('lean', 8),
#  ('exterior', 8),
#  ('upcoming', 8),
#  ('make-up', 8),
#  ('mango', 8),
#  ('smokey', 8),
#  ('tapas', 8),
#  ('silky', 8),
#  ('severe', 7),
#  ('long-time', 7),
#  ('guys', 7),
#  ('rear', 7),
#  ('candied', 7),
#  ('Generous', 7),
#  ('functional', 7),
#  ('fanatic', 7),
#  ('relative', 7),
#  ('bite', 7),
#  ('sincere', 7),
#  ('unhappy', 7),
#  ('elderly', 7),
#  ('caprese', 7),
#  ('6-7', 7),
#  ('Cheap', 7),
#  ('soup', 7),
#  ('horseradish', 7),
#  ('Classic', 7),
#  ('diagnostic', 7),
#  ('supportive', 7),
#  ('Polish', 7),
#  ('fondue', 7),
#  ('miso', 7),
#  ('obsessed', 7),
#  ('conservative', 7),
#  ('pro', 7),
#  ('bottom', 7),
#  ('appreciated', 7),
#  ...]

# %%
one_star['adjectives'] = one_star.adjectives.apply(' '.join)
one_star
# Out:
# <ipython-input-41-9c4a9448f828>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_star['adjectives'] = one_star.adjectives.apply(' '.join)
#        Stars                                             Review  \
# 0          1  I got 'new' tires from them and within two wee...
# 1          1  Don't waste your time. We had two different pe...
# 2          1  All I can say is the worst! We were the only 2...
# 3          1  I have been to this restaurant twice and was d...
# 4          1  Food was NOT GOOD at all! My husband & I ate h...
# ...      ...                                                ...
# 49870      1  Not worth the time, much less the price of adm...
# 49871      1  Not worth the time, much less the price of adm...
# 49872      1  The Marvel Experience, more like I took your m...
# 49873      1  Just wanted to write a review to chip in with ...
# 49877      1  Buffet was recently open after renovation so m...
#
#                                               adjectives
# 0      flat local previous new resentful unlikely new...
# 1                                              different
# 2      only electronic fish filthy slimy cold small s...
# 3      first empty rude Ridiculous long cold cold dis...
# 4      first huge much runny/watery much enough bad e...
# ...                                                  ...
# 49870  colorful small bitter several expensive whole ...
# 49871  colorful small bitter several expensive whole ...
# 49872                                       3-D 4-D long
# 49873          little worth accurate same cool only cool
# 49877  open good wrong same upgrade looked brownish o...
#
# [9964 rows x 3 columns]

# %%
Counter(" ".join(one_star["adjectives"]).split()).most_common()
# Out:
# [('good', 3092),
#  ('other', 2397),
#  ('bad', 1857),
#  ('first', 1372),
#  ('great', 1250),
#  ('last', 1204),
#  ('same', 1141),
#  ('new', 1134),
#  ('few', 1089),
#  ('much', 1015),
#  ('next', 995),
#  ('sure', 966),
#  ('nice', 962),
#  ('many', 937),
#  ('little', 897),
#  ('horrible', 850),
#  ('old', 798),
#  ('only', 769),
#  ('small', 732),
#  ('terrible', 729),
#  ('rude', 692),
#  ('wrong', 678),
#  ('different', 673),
#  ('long', 629),
#  ('big', 579),
#  ('free', 571),
#  ('full', 547),
#  ('whole', 535),
#  ('poor', 519),
#  ('busy', 509),
#  ('hot', 504),
#  ('second', 494),
#  ('several', 493),
#  ('right', 471),
#  ('cold', 470),
#  ('disappointed', 451),
#  ('happy', 449),
#  ('hard', 448),
#  ('open', 444),
#  ('such', 415),
#  ('extra', 406),
#  ('empty', 404),
#  ('able', 404),
#  ('fine', 404),
#  ('dry', 400),
#  ('high', 400),
#  ('awful', 400),
#  ('own', 382),
#  ('special', 362),
#  ('fresh', 349),
#  ('entire', 349),
#  ('ready', 336),
#  ('slow', 334),
#  ('large', 329),
#  ('real', 322),
#  ('i', 322),
#  ('due', 321),
#  ('expensive', 316),
#  ('decent', 312),
#  ('worth', 310),
#  ('cheap', 298),
#  ('friendly', 297),
#  ('ok', 286),
#  ('dirty', 269),
#  ('available', 265),
#  ('short', 265),
#  ('huge', 261),
#  ('clean', 256),
#  ('regular', 250),
#  ('Horrible', 248),
#  ('ridiculous', 236),
#  ('local', 226),
#  ('late', 220),
#  ('super', 218),
#  ('white', 209),
#  ('possible', 205),
#  ('low', 203),
#  ('sick', 200),
#  ('sorry', 200),
#  ('nasty', 199),
#  ('cheese', 196),
#  ('past', 195),
#  ('young', 193),
#  ('gross', 193),
#  ('enough', 191),
#  ('disappointing', 189),
#  ('unprofessional', 188),
#  ('negative', 187),
#  ('sad', 186),
#  ('single', 186),
#  ('hungry', 185),
#  ('tiny', 182),
#  ('frozen', 182),
#  ('black', 180),
#  ('Terrible', 179),
#  ('loud', 178),
#  ('main', 175),
#  ('simple', 173),
#  ('total', 169),
#  ('pretty', 169),
#  ('outside', 167),
#  ('half', 166),
#  ('red', 165),
#  ('normal', 163),
#  ('complete', 162),
#  ('front', 158),
#  ('clear', 158),
#  ('additional', 155),
#  ('cool', 153),
#  ('quick', 153),
#  ('sweet', 151),
#  ('previous', 150),
#  ('multiple', 149),
#  ('average', 148),
#  ('fried', 147),
#  ('green', 147),
#  ('helpful', 146),
#  ('corporate', 144),
#  ('Good', 143),
#  ('soggy', 141),
#  ('*', 141),
#  ('Chinese', 136),
#  ('positive', 136),
#  ('fish', 135),
#  ('warm', 131),
#  ('top', 130),
#  ('dead', 128),
#  ('flat', 126),
#  ('greasy', 126),
#  ('early', 125),
#  ('actual', 125),
#  ('professional', 124),
#  ('....', 123),
#  ('original', 123),
#  ('personal', 122),
#  ('third', 122),
#  ('..', 122),
#  ('tough', 120),
#  ('stupid', 119),
#  ('delicious', 118),
#  ('okay', 117),
#  ('weird', 117),
#  ('true', 117),
#  ('favorite', 116),
#  ('awesome', 115),
#  ('Italian', 113),
#  ('crappy', 112),
#  ('willing', 111),
#  ('close', 110),
#  ('particular', 110),
#  ('important', 110),
#  ('upset', 109),
#  ('overall', 106),
#  ('raw', 106),
#  ('pleasant', 105),
#  ('interested', 104),
#  ('difficult', 104),
#  ('thin', 104),
#  ('unacceptable', 103),
#  ('general', 102),
#  ('basic', 102),
#  ('amazing', 101),
#  ('sour', 100),
#  ('uncomfortable', 100),
#  ('Mexican', 99),
#  ('table', 98),
#  ('crazy', 98),
#  ('tasteless', 97),
#  ('correct', 96),
#  ('major', 96),
#  ('certain', 96),
#  ('Last', 95),
#  ('tasty', 95),
#  ('excellent', 95),
#  ('u', 95),
#  ('Overall', 94),
#  ('easy', 94),
#  ('Asian', 94),
#  ('serious', 92),
#  ('back', 91),
#  ('like', 89),
#  ('Next', 87),
#  ('wait', 87),
#  ('similar', 86),
#  ('beautiful', 85),
#  ('French', 84),
#  ('stale', 84),
#  ('garlic', 84),
#  ('double', 83),
#  ('authentic', 83),
#  ('rental', 83),
#  ('fast', 82),
#  ('filthy', 81),
#  ('deep', 81),
#  ('excited', 80),
#  ('Other', 80),
#  ('separate', 80),
#  ('unhappy', 79),
#  ('angry', 79),
#  ('safe', 79),
#  ('usual', 78),
#  ('odd', 78),
#  ('exact', 78),
#  ('funny', 78),
#  ('fair', 78),
#  ('couple', 77),
#  ('wonderful', 77),
#  ('glad', 77),
#  ('recent', 76),
#  ('obvious', 76),
#  ('light', 76),
#  ('mediocre', 75),
#  ('impressed', 75),
#  ('unable', 75),
#  ('inedible', 74),
#  ('prime', 73),
#  ('reasonable', 73),
#  ('edible', 73),
#  ('perfect', 73),
#  ('aware', 72),
#  ('common', 72),
#  ('surprised', 70),
#  ('undercooked', 70),
#  ('soft', 69),
#  ('dark', 68),
#  ('limited', 68),
#  ('mad', 67),
#  ('incompetent', 65),
#  ('chicken', 65),
#  ('comfortable', 65),
#  ('mixed', 64),
#  ('final', 64),
#  ('strong', 64),
#  ('proper', 64),
#  ('strange', 63),
#  ('likely', 63),
#  ('Indian', 62),
#  ('non', 62),
#  ('grilled', 62),
#  ('overpriced', 61),
#  ('acceptable', 61),
#  ('lousy', 61),
#  ('lazy', 60),
#  ('lucky', 60),
#  ('french', 60),
#  ('typical', 60),
#  ('burnt', 60),
#  ('attentive', 59),
#  ('polish', 59),
#  ('impossible', 59),
#  ('heavy', 58),
#  ('First', 58),
#  ('fat', 58),
#  ('nail', 58),
#  ('vegetarian', 57),
#  ('potential', 57),
#  ('miserable', 57),
#  ('standard', 57),
#  ('salty', 56),
#  ('sushi', 56),
#  ('Japanese', 56),
#  ('online', 55),
#  ('rare', 55),
#  ('fantastic', 55),
#  ('numerous', 55),
#  ('un', 55),
#  ('used', 54),
#  ('private', 54),
#  ('Second', 53),
#  ('unfortunate', 53),
#  ('specific', 53),
#  ('thick', 53),
#  ('Korean', 53),
#  ('apologetic', 53),
#  ('blue', 52),
#  ('iced', 52),
#  ('broken', 52),
#  ('careful', 51),
#  ('absolute', 51),
#  ('polite', 51),
#  ('shitty', 50),
#  ('sticky', 50),
#  ('ten', 49),
#  ('medical', 49),
#  ('salad', 48),
#  ('unpleasant', 48),
#  ('shady', 48),
#  ('female', 48),
#  ('OK', 47),
#  ('social', 47),
#  ('mexican', 47),
#  ('following', 46),
#  ('live', 46),
#  ('brown', 46),
#  ('loyal', 46),
#  ('healthy', 46),
#  ('human', 45),
#  ('bitter', 45),
#  ('bright', 44),
#  ('traditional', 44),
#  ('generous', 44),
#  ('unhelpful', 44),
#  ('flavorless', 44),
#  ('cooked', 44),
#  ('initial', 44),
#  ('quiet', 44),
#  ('drunk', 43),
#  ('horrendous', 43),
#  ('necessary', 43),
#  ('concerned', 43),
#  ('weak', 42),
#  ('pathetic', 42),
#  ('rough', 42),
#  ('random', 42),
#  ('giant', 41),
#  ('interesting', 41),
#  ('mushy', 40),
#  ('upscale', 40),
#  ('fake', 40),
#  ('chewy', 40),
#  ('current', 40),
#  ('Total', 40),
#  ('mean', 39),
#  ('rid', 39),
#  ('key', 39),
#  ('puppy', 39),
#  ('pizza', 39),
#  ('cute', 39),
#  ('further', 39),
#  ('complimentary', 38),
#  ('atrocious', 38),
#  ('welcome', 38),
#  ('picky', 38),
#  ('straight', 38),
#  ('u00e0', 38),
#  ('Big', 37),
#  ('popular', 37),
#  ('monthly', 37),
#  ('bottom', 37),
#  ('joint', 36),
#  ('useless', 36),
#  ('various', 36),
#  ('apparent', 36),
#  ('tired', 36),
#  ('grand', 36),
#  ('sub', 36),
#  ('incorrect', 36),
#  ('noodle', 36),
#  ('outrageous', 36),
#  ('American', 36),
#  ('Happy', 36),
#  ('fellow', 36),
#  ('10-15', 36),
#  ('fancy', 35),
#  ('appropriate', 35),
#  ('wet', 35),
#  ('.....', 35),
#  ('unfriendly', 35),
#  ('fatty', 35),
#  ('obnoxious', 35),
#  ('painful', 35),
#  ('Such', 35),
#  ('confused', 35),
#  ('baked', 34),
#  ('impressive', 34),
#  ('frustrated', 34),
#  ('familiar', 34),
#  ('bland', 34),
#  ('false', 34),
#  ('sloppy', 33),
#  ('boring', 33),
#  ('dish', 33),
#  ('solid', 33),
#  ('lunch', 33),
#  ('tall', 33),
#  ('prior', 33),
#  ('Many', 32),
#  ('enjoyable', 32),
#  ('pleased', 32),
#  ('plastic', 32),
#  ('suppose', 32),
#  ('disrespectful', 32),
#  ('wish', 32),
#  ('irritated', 32),
#  ('dumb', 31),
#  ('annoyed', 31),
#  ('convenient', 31),
#  ('modern', 31),
#  ('lame', 31),
#  ('direct', 31),
#  ('yellow', 31),
#  ('daily', 31),
#  ('inattentive', 30),
#  ('unique', 30),
#  ('Wish', 30),
#  ('Great', 30),
#  ('arrogant', 30),
#  ('horrid', 30),
#  ('plain', 30),
#  ('understaffed', 29),
#  ('left', 29),
#  ('diet', 29),
#  ('sub-par', 29),
#  ('shredded', 29),
#  ('future', 29),
#  ('gel', 29),
#  ('smart', 28),
#  ('dental', 28),
#  ('frequent', 28),
#  ('snotty', 28),
#  ('famous', 28),
#  ('n', 28),
#  ('Vietnamese', 28),
#  ('nearby', 28),
#  ('vegetable', 28),
#  ('dangerous', 28),
#  ('severe', 28),
#  ('dessert', 28),
#  ('frustrating', 28),
#  ('worst', 28),
#  ('timely', 27),
#  ('birthday', 27),
#  ('overcooked', 27),
#  ('to-go', 27),
#  ('mine', 27),
#  ('courteous', 27),
#  ('public', 27),
#  ('entree', 27),
#  ('awkward', 27),
#  ('asian', 27),
#  ('absurd', 27),
#  ('minimal', 27),
#  ('Ridiculous', 26),
#  ('prepared', 26),
#  ('loose', 26),
#  ('blank', 26),
#  ('sandwich', 26),
#  ('crowded', 26),
#  ('chinese', 26),
#  ('hidden', 26),
#  ('2-3', 26),
#  ('outstanding', 26),
#  ('aggressive', 26),
#  ('fabulous', 26),
#  ('ur', 26),
#  ('questionable', 26),
#  ('minimum', 26),
#  ('wine', 26),
#  ('lukewarm', 25),
#  ('flavorful', 25),
#  ('retail', 25),
#  ('Wrong', 25),
#  ('english', 25),
#  ('sudden', 25),
#  ('afraid', 25),
#  ('unbelievable', 25),
#  ('shit', 25),
#  ('classic', 25),
#  ('taco', 25),
#  ('oh', 25),
#  ('scary', 25),
#  ('Unbelievable', 25),
#  ('Spanish', 25),
#  ('desperate', 25),
#  ('non-smoking', 25),
#  ('superior', 25),
#  ('over-priced', 24),
#  ('Awful', 24),
#  ('consistent', 24),
#  ('closed', 24),
#  ('steak', 24),
#  ('present', 24),
#  ('lackluster', 24),
#  ('visible', 24),
#  ('stellar', 24),
#  ('responsible', 24),
#  ('Sure', 24),
#  ('15-20', 24),
#  ('disgusting', 23),
#  ('pure', 23),
#  ('luke', 23),
#  ('unorganized', 23),
#  ('technician', 23),
#  ('weekly', 23),
#  ('Several', 23),
#  ('pregnant', 23),
#  ('tasted', 23),
#  ('natural', 23),
#  ('constant', 23),
#  ('annual', 23),
#  ('organic', 23),
#  ('olive', 23),
#  ('ordered', 23),
#  ('3-4', 22),
#  ('so-so', 22),
#  ('ill', 22),
#  ('memorable', 22),
#  ('middle', 22),
#  ('elderly', 22),
#  ('ive', 22),
#  ('inexpensive', 22),
#  ('patient', 22),
#  ('lovely', 22),
#  ('shrimp', 22),
#  ('generic', 22),
#  ('furious', 22),
#  ('attractive', 22),
#  ('massive', 22),
#  ('fishy', 22),
#  ('dont', 22),
#  ('packed', 22),
#  ('incredible', 21),
#  ('vegan', 21),
#  ('shocked', 21),
#  ('east', 21),
#  ('20-30', 21),
#  ('Little', 21),
#  ('honest', 21),
#  ('significant', 21),
#  ('ok.', 21),
#  ('extreme', 21),
#  ('former', 21),
#  ('pushy', 21),
#  ('urgent', 21),
#  ('carne', 21),
#  ('needless', 21),
#  ('defensive', 21),
#  ('fun', 21),
#  ('une', 21),
#  ('sanitary', 20),
#  ('culinary', 20),
#  ('unnecessary', 20),
#  ('sarcastic', 20),
#  ('ordinary', 20),
#  ('creamy', 20),
#  ('scheduled', 20),
#  ('rotten', 20),
#  ('website', 20),
#  ('pretentious', 20),
#  ('gorgeous', 20),
#  ('dusty', 20),
#  ('spectacular', 20),
#  ('knowledgeable', 20),
#  ('unsatisfied', 20),
#  ('pulled', 20),
#  ('marginal', 20),
#  ('individual', 20),
#  ('ghetto', 20),
#  ('Irish', 20),
#  ('near', 19),
#  ('insulting', 19),
#  ('unsafe', 19),
#  ('secret', 19),
#  ('animal', 19),
#  ('casual', 19),
#  ('exceptional', 19),
#  ('indian', 19),
#  ('stressful', 19),
#  ('successful', 19),
#  ('dissatisfied', 19),
#  ('horrific', 19),
#  ('pissed', 19),
#  ('2nd', 19),
#  ('upgraded', 19),
#  ('canned', 19),
#  ('sharp', 19),
#  ('comparable', 19),
#  ('outdoor', 19),
#  ('im', 19),
#  ('inappropriate', 19),
#  ('buffet', 19),
#  ('clueless', 18),
#  ('facial', 18),
#  ('square', 18),
#  ('Small', 18),
#  ('tacky', 18),
#  ('illegal', 18),
#  ('pricey', 18),
#  ('inside', 18),
#  ('noisy', 18),
#  ('central', 18),
#  ('valid', 18),
#  ('4-5', 18),
#  ('deli', 18),
#  ('appointment', 18),
#  ('unavailable', 18),
#  ('dive', 18),
#  ('trained', 18),
#  ('accurate', 18),
#  ('WRONG', 18),
#  ('satisfied', 18),
#  ('utter', 18),
#  ('allergic', 18),
#  ('skinny', 18),
#  ('lemon', 18),
#  ('uneven', 18),
#  ('male', 18),
#  ('affordable', 18),
#  ('bottle', 18),
#  ('nous', 18),
#  ('dining', 17),
#  ('tight', 17),
#  ('Hawaiian', 17),
#  ('classy', 17),
#  ('below', 17),
#  ('shuttle', 17),
#  ('fourth', 17),
#  ('financial', 17),
#  ('livid', 17),
#  ('stuck', 17),
#  ('upstairs', 17),
#  ('refried', 17),
#  ('reputable', 17),
#  ('inexcusable', 17),
#  ('arrive', 17),
#  ('nervous', 17),
#  ('ONLY', 17),
#  ('worthy', 17),
#  ('wide', 17),
#  ('watery', 17),
#  ('advertised', 17),
#  ('downright', 17),
#  ('messy', 17),
#  ('unusual', 17),
#  ('please', 17),
#  ('unimpressed', 17),
#  ('check-in', 17),
#  ('runny', 17),
#  ('restaurant', 17),
#  ('spicy', 17),
#  ('queen', 17),
#  ('go-to', 16),
#  ('limp', 16),
#  ('balsamic', 16),
#  ('ignorant', 16),
#  ('rear', 16),
#  ('legal', 16),
#  ('defective', 16),
#  ('ugh', 16),
#  ('foreign', 16),
#  ('harsh', 16),
#  ('pro', 16),
#  ('Greek', 16),
#  ('called', 16),
#  ('curious', 16),
#  ('south', 16),
#  ('formal', 16),
#  ('unreasonable', 16),
#  ('reliable', 16),
#  ('5-10', 16),
#  ('bread', 16),
#  ('waitress', 16),
#  ('spa', 16),
#  ('understanding', 16),
#  ('subpar', 16),
#  ('le', 16),
#  ('slimy', 15),
#  ('premium', 15),
#  ('everyday', 15),
#  ('else', 15),
#  ('Due', 15),
#  ('downtown', 15),
#  ('cafe', 15),
#  ('complex', 15),
#  ('scared', 15),
#  ('understandable', 15),
#  ('soooo', 15),
#  ('steep', 15),
#  ('thank', 15),
#  ('military', 15),
#  ('spacious', 15),
#  ('fifteen', 15),
#  ('kinda', 15),
#  ('awhile', 15),
#  ('scam', 15),
#  ('Same', 15),
#  ('abysmal', 15),
#  ('Long', 15),
#  ('later', 15),
#  ('smoked', 15),
#  ('instant', 15),
#  ('interior', 15),
#  ('damn', 14),
#  ('passable', 14),
#  ('legitimate', 14),
#  ('cant', 14),
#  ('critical', 14),
#  ('sized', 14),
#  ('so-called', 14),
#  ('detailed', 14),
#  ('inconsistent', 14),
#  ('wasted', 14),
#  ('email', 14),
#  ('routine', 14),
#  ('mid', 14),
#  ('liquid', 14),
#  ('confident', 14),
#  ('worn', 14),
#  ('electrical', 14),
#  ('pet', 14),
#  ('+', 14),
#  ('laundry', 14),
#  ('plus', 14),
#  ('turkey', 14),
#  ('unwilling', 14),
#  ('uncooked', 14),
#  ('upper', 14),
#  ('refundable', 14),
#  ('golden', 14),
#  ('German', 14),
#  ('seasoned', 14),
#  ('bean', 14),
#  ('English', 14),
#  ('crab', 14),
#  ('ice', 14),
#  ('valuable', 14),
#  ('GOOD', 14),
#  ('alright', 14),
#  ('hostile', 14),
#  ('alcoholic', 14),
#  ('kitchen', 14),
#  ('sooo', 14),
#  ('experienced', 14),
#  ('precious', 14),
#  ('@', 14),
#  ('bottled', 14),
#  ('pink', 14),
#  ('Brazilian', 14),
#  ('north', 13),
#  ('unwelcome', 13),
#  ('freaking', 13),
#  ('steamed', 13),
#  ('creative', 13),
#  ('overnight', 13),
#  ('automatic', 13),
#  ('minute', 13),
#  ('somewhere', 13),
#  ('senior', 13),
#  ('text', 13),
#  ('excessive', 13),
#  ('mechanic', 13),
#  ('trendy', 13),
#  ('adequate', 13),
#  ('extensive', 13),
#  ('naked', 13),
#  ('piss', 13),
#  ('dreadful', 13),
#  ('borderline', 13),
#  ('scramble', 13),
#  ('tomato', 13),
#  ('told', 13),
#  ('funky', 13),
#  ('Red', 13),
#  ('dull', 13),
#  ('native', 13),
#  ('commercial', 13),
#  ('pasta', 13),
#  ('torn', 13),
#  ('indifferent', 13),
#  ('quality', 13),
#  ('Complete', 13),
#  ('fraudulent', 13),
#  ('dingy', 13),
#  ('pre-made', 13),
#  ('um', 13),
#  ('eating', 13),
#  ('racial', 13),
#  ('down', 13),
#  ('efficient', 13),
#  ('nicer', 13),
#  ('ear', 13),
#  ('inconvenient', 13),
#  ('tolerable', 13),
#  ('drive', 13),
#  ('Free', 13),
#  ('personable', 13),
#  ('bizarre', 13),
#  ('electronic', 12),
#  ('competitive', 12),
#  ('dog', 12),
#  ('added', 12),
#  ('non-existent', 12),
#  ('understatement', 12),
#  ('crunchy', 12),
#  ('appalled', 12),
#  ('laughable', 12),
#  ('stuff', 12),
#  ('unapologetic', 12),
#  ('silent', 12),
#  ('electric', 12),
#  ('1-star', 12),
#  ('eggplant', 12),
#  ('snow', 12),
#  ('Whole', 12),
#  ('physical', 12),
#  ('worse', 12),
#  ('tonight', 12),
#  ('legit', 12),
#  ('sufficient', 12),
#  ('disgusted', 12),
#  ('Which', 12),
#  ('confusing', 12),
#  ('skeptical', 12),
#  ('update', 12),
#  ('side', 12),
#  ('drive-thru', 12),
#  ('soo', 12),
#  ('mandatory', 12),
#  ('tried', 12),
#  ('hilarious', 12),
#  ('unclean', 12),
#  ('gracious', 12),
#  ('1st', 12),
#  ('dated', 12),
#  ('meal', 12),
#  ('ta', 12),
#  ('annoying', 12),
#  ('sexual', 12),
#  ('na', 12),
#  ('opposite', 12),
#  ('upgrade', 12),
#  ('underwhelming', 12),
#  ('guys', 12),
#  ('visual', 12),
#  ('epic', 11),
#  ('italian', 11),
#  ('thai', 11),
#  ('4th', 11),
#  ('condescending', 11),
#  ('wild', 11),
#  ('lumpy', 11),
#  ('poorly', 11),
#  ('spanish', 11),
#  ('Special', 11),
#  ('rave', 11),
#  ('3-5', 11),
#  ('overrated', 11),
#  ('anxious', 11),
#  ('noticeable', 11),
#  ('didnt', 11),
#  ('temporary', 11),
#  ('mental', 11),
#  ('web', 11),
#  ('6-8', 11),
#  ('drink', 11),
#  ('outdated', 11),
#  ('relaxing', 11),
#  ('abrupt', 11),
#  ('callous', 11),
#  ('mashed', 11),
#  ('Expensive', 11),
#  ('inch', 11),
#  ('embarrassed', 11),
#  ('Green', 11),
#  ('careless', 11),
#  ('overwhelming', 11),
#  ('mild', 11),
#  ('upfront', 11),
#  ('crispy', 11),
#  ('upsetting', 11),
#  ('nachos', 11),
#  ('gluten', 11),
#  ('lady', 11),
#  ('Huge', 11),
#  ('give', 11),
#  ('unsatisfactory', 11),
#  ('surly', 11),
#  ('artificial', 11),
#  ('Venetian', 11),
#  ('tap', 11),
#  ('nauseous', 11),
#  ('promising', 11),
#  ('appetizer', 11),
#  ('Mongolian', 11),
#  ('amongst', 10),
#  ('sunny', 10),
#  ('egregious', 10),
#  ('dissapointed', 10),
#  ('degree', 10),
#  ('forgettable', 10),
#  ('let', 10),
#  ('automated', 10),
#  ('freakin', 10),
#  ('rich', 10),
#  ('f', 10),
#  ('NOT', 10),
#  ('RUDE', 10),
#  ('dried', 10),
#  ('neat', 10),
#  ('on-line', 10),
#  ('cramped', 10),
#  ('hear', 10),
#  ('smooth', 10),
#  ('spent', 10),
#  ('eaten', 10),
#  ('vacant', 10),
#  ('miss', 10),
#  ('mere', 10),
#  ('chili', 10),
#  ('ideal', 10),
#  ('suspicious', 10),
#  ('equal', 10),
#  ('pale', 10),
#  ('5-6', 10),
#  ('5th', 10),
#  ('bloody', 10),
#  ('curly', 10),
#  ('partial', 10),
#  ('costly', 10),
#  ('subject', 10),
#  ('argumentative', 10),
#  ('oz', 10),
#  ('skimpy', 10),
#  ('evident', 10),
#  ('theirs', 10),
#  ('sooooo', 10),
#  ('fifth', 10),
#  ('pho', 10),
#  ('utterly', 10),
#  ('better', 10),
#  ('sketchy', 10),
#  ('greedy', 10),
#  ('sigh', 10),
#  ('unappetizing', 10),
#  ('spoiled', 10),
#  ('uninterested', 10),
#  ('offended', 10),
#  ('Wait', 10),
#  ('couch', 10),
#  ('brief', 10),
#  ('surprising', 10),
#  ('snarky', 10),
#  ('30th', 10),
#  ('worthless', 10),
#  ('offensive', 10),
#  ('lengthy', 10),
#  ('magical', 10),
#  ('respectful', 10),
#  ('unused', 10),
#  ('hesitant', 10),
#  ('untrained', 10),
#  ('semi', 10),
#  ('internet', 10),
#  ('soy', 10),
#  ('chopped', 10),
#  ('combo', 10),
#  ('twenty', 10),
#  ('unsanitary', 10),
#  ('salmon', 10),
#  ('idiotic', 9),
#  ('faux', 9),
#  ('......', 9),
#  ('ethnic', 9),
#  ('criminal', 9),
#  ('shoddy', 9),
#  ('tip', 9),
#  ('domestic', 9),
#  ('blatant', 9),
#  ('salt', 9),
#  ('immediate', 9),
#  ('estimated', 9),
#  ('uniform', 9),
#  ('identical', 9),
#  ('dismissive', 9),
#  ('minor', 9),
#  ('European', 9),
#  ('MANY', 9),
#  ('skin', 9),
#  ('hefty', 9),
#  ('thirty', 9),
#  ('smile', 9),
#  ('chaotic', 9),
#  ('genuine', 9),
#  ('thorough', 9),
#  ('1-2', 9),
#  ('Much', 9),
#  ('iceberg', 9),
#  ('unethical', 9),
#  ('trashy', 9),
#  ('cocky', 9),
#  ('narrow', 9),
#  ('above', 9),
#  ('depressing', 9),
#  ('uncaring', 9),
#  ('unexpected', 9),
#  ('inefficient', 9),
#  ('gray', 9),
#  ('nurse', 9),
#  ('yearly', 9),
#  ('touch', 9),
#  ('eligible', 9),
#  ('chipotle', 9),
#  ('follow-up', 9),
#  ('impatient', 9),
#  ('Jewish', 9),
#  ('dismal', 9),
#  ('apathetic', 9),
#  ('insane', 9),
#  ('Large', 9),
#  ('ample', 9),
#  ...]
